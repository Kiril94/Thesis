# %%
import nilearn
import matplotlib.pyplot as plt
import numpy as np

# %%
from nilearn import plotting
nib.Nifti1Header.quaternion_threshold = -1e-06
import nibabel as nib

# %%
x = nib.load("F:\\CoBra\\Data\\volume_longitudinal_nii\\input\\nii_files\\segmented\\001622.nii.gz")
y = nib.load("F:\\CoBra\\Data\\volume_longitudinal_nii\\prediction\\001622_seg.nii.gz")

# %%
display = plotting.plot_img(x, cmap='gray', cut_coords=(30, 5, 0))
display.add_overlay(y, cmap='videen_style', threshold=0, )

# %%
from nilearn import plotting
from nilearn import datasets

#dataset_ho = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm')
#dataset_ju = datasets.fetch_atlas_juelich('maxprob-thr0-1mm')
fig, ax = plt.subplots(figsize=(10,10))
#atlas_ju_filename = dataset_ju.filename
plot = plotting.plot_roi("C:\\Users\\kiril\\Thesis\\CoBra\\cobra\\writeup\\Introduction\\brain_regions_vis\\template_638.nii", 
    axes=ax,annotate=False,
    figure=fig, draw_cross=False, colorbar=True,  cmap='Paired',)
cbar = plot._cbar
cbar.set_ticks(np.arange(1,633,100))
#cbar.ax.set_yticks(np.arange(10))
#cbar.ax.set_yticklabels(10*['test'])
#fig.colorbar()

# %%
plot._colorbar_width
# Out:
# 0.03875000000000001

# %%
plot._cbar

# %%
print(dir(plot))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_axes_class', '_black_bg', '_brain_color', '_cbar', '_cbar_tick_format', '_colorbar', '_colorbar_ax', '_colorbar_margin', '_colorbar_width', '_cut_displayed', '_default_figsize', '_init_axes', '_locator', '_map_show', '_show_colorbar', 'add_contours', 'add_edges', 'add_markers', 'add_overlay', 'annotate', 'axes', 'black_bg', 'brain_color', 'close', 'cut_coords', 'draw_cross', 'find_cut_coords', 'frame_axes', 'init_with_figure', 'rect', 'savefig', 'title']
