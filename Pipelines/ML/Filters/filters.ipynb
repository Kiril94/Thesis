# %%
import matplotlib.pyplot as plt
from scipy import signal
from skimage.measure import block_reduce
import numpy as np
import matplotlib as mpl
from skimage.feature import hog
from skimage import data, exposure
# %config InlineBackend.figure_format = 'retina'
from scipy import ndimage
from skimage.transform import rescale, resize, downscale_local_mean

# %% [markdown]
# ## Example image

# %%
img = plt.imread(r"nastja.jpg")
fig, ax = plt.subplots()
image_resized = resize(img, (img.shape[0] // 20, img.shape[1] // 20),
                        anti_aliasing=True)
ax.imshow(image_resized)

# %% [markdown]
# ## HOG

# %%
image = image_resized

fd, hog_image = hog(image, orientations=4, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram f`or better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
plt.show()

# %%
ker1 = np.array([[1/16, 1/8, 1/16],   #3x3 kernel
                [1/8, 1/4, 1/8],
                [1/16, 1/8, 1/16]])
img_gauss = apply_rgb(apply_rgb(apply_rgb(img, ker1), ker1), ker1)
plt.imshow(img_gauss)

# %%
_ = plt.hist(np.ndarray.flatten(img_gauss), 100)

# %% [markdown]
# # Steerable filters

# %%
def apply_rgb(img, f):
    img_list = [signal.convolve(img[:,:,i], f, mode='same') for i in range(3)]
    img_n = np.stack(img_list, axis=2)
    img_n = np.array(img_n, dtype=int)
    return img_n

def circular_kernel(theta):
    e = np.exp(1)
    G0 = 2/e**2*np.array([[1,0, -1],
                         [e, 0 ,-e],
                         [1,0,-1]])
    G1 = 2/e**2*np.array([[-1,-e, -1],
                         [0, 0 ,0],
                         [1,e,1]])
    f = np.cos(theta)*G0 + np.sin(theta)*G1
    return f
def apply_filter(img, f):
    img = signal.convolve(img, f, mode='same')
    return img

# %%
sobel = np.array([[1,0,-1],[2,0,-2],[1,0,-1]])
kernel = np.array([[-1,1,0],[-1,1,0],[-1,1,0]])
circ_f = circular_kernel(0)
avg_kernel = np.array([[0,.25,0],
                       [.25,0,.25],
                       [0,.25,0]])
img_n = apply_rgb(img, circ_f)
fig, ax = plt.subplots(2,2, figsize=(15,15))
ax = ax.flatten()
for i,a in enumerate(ax):
    theta = i*2*np.pi/4
    img_n = apply_rgb(img, circular_kernel(theta))
    a.set_title(f"{theta/(2*np.pi)*360}")
    a.imshow(img_n)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Finite group transformations

# %% [markdown]
# ## Simple example

# %%
img_l = np.zeros((100,100))
img_l[20:80, 40:45] = 1
img_l[80:85,40:70] = 1
plt.imshow(img_l)

# %%
f0 = np.array([[1,0,-1],
            [1,0,-1],
             [1,0,-1]])
def rotate_90(f):
    return np.rot90(f, axes=(0,1))
def mirror(f, axis):
    return np.flip(f,axis)
f1 = rotate_90(f0)
f2 = rotate_90(f1)
f3 = rotate_90(f2)
filters = [f0, f1, f2, f3]

# %%
img_flipped = mirror(img_l, 0)
plt.imshow(img_flipped)

# %% [markdown]
# ### rotate img

# %%
img_l1 = rotate_90(img_l)
img_l2 = rotate_90(img_l1)
img_l3 = rotate_90(img_l2)
images = [img_l, img_l1, img_l2, img_l3]

# %%
fig, ax = plt.subplots(4,4, figsize=(10,10))
for i,f in enumerate(filters):
    for j, img in enumerate(images):
        fm = apply_filter(img, f)
        ax[i,j].imshow(fm)
